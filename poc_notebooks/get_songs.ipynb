# %%
import requests

# %%
url = 'https://qakwwzhiv5.execute-api.eu-central-1.amazonaws.com/prod/api/getListaItems?phase=dev-fm-'

# %%
# Get the list of songs
r = requests.get(url)
songs = r.json()

# %%
import pandas as pd

# %%
songs.keys()
# Out:
# dict_keys(['itemsWithPista'])

# %%
pd.DataFrame(songs['itemsWithPista'])
# Out:
#    currentPosition previousPosition weeksInList  code  \
# 0                1                1           7  0757
# 1                2                7           6  0802
# 2                3                3          11  0512
# 3                4                2           9  0715
# 4                5                5           9  0668
# 5                6               11           5  0814
# 6                7                4          14  0374
# 7                8                6          17  0322
# 8                9               12           8  0553
# 9               10                8          10  0620
# 10              11                9          15  0352
# 11              12               15           8  0724
# 12              13               10          13  0450
# 13              14               20           5  0809
# 14              15               13          21  0149
# 15              16               14          20  0144
# ...
